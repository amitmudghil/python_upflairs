# %%
###  Pandas Features ###
########################
# 1. String Functions
# 2. Merging/Joining
# 3. Missing Data
# 4. Statistical
# 5. Data iteration
# 6. Data Grouping
# 7. Aggregation
# 8. Sorting

# %%
import pandas as pd

# %%
df = pd.read_csv(r'suicide_data/suicide_data.csv', index_col = 0)
df.head()
# Out:
#             State/UT  By Consuming Sleeping Pills - Total  \
# 0     Andhra Pradesh                                   44
# 1  Arunachal Pradesh                                    0
# 2              Assam                                    8
# 3              Bihar                                   55
# 4       Chhattisgarh                                    0
#
#    By Drowning - Transgender  By Fire/Self Immolation - Female  \
# 0                          0                                47
# 1                          0                                 0
# 2                          0                                10
# 3                          0                                 9
# 4                          0                               270
#
#    By Firearms - Male  By Firearms - Total  By Hanging - Transgender  \
# 0                   3                    4                         0
# 1                   2                    2                         0
# ...

# %%
df['State/UT'].str.count('a')#returns count of letter a
df['State/UT'].str.contains('a')
df['State/UT'].str.find('a') # find the position first occurence of the letter 
df['State/UT'].str.get_dummies() # create unique dataframe for all values of state/UT column
df['State/UT'].str.get(-1)
df['State/UT'].str.join('+')
df['State/UT'].str.lower()
df['State/UT'].str.count('a')
#df['State/UT'].str.repeat([3,4,2,4,2,4,2,2,5,7,3,3,5,2,3,5,4,5,6,7])
df['State/UT'].str.replace('a','k',case=False)
df['State/UT'].str.upper()
df['State/UT'].str.split().str.get(0)
# Out:
# 0           Andhra
# 1        Arunachal
# 2            Assam
# 3            Bihar
# 4     Chhattisgarh
# 5              Goa
# 6          Gujarat
# 7          Haryana
# 8         Himachal
# 9        Jharkhand
# 10       Karnataka
# 11          Kerala
# 12          Madhya
# 13     Maharashtra
# 14         Manipur
# 15       Meghalaya
# 16         Mizoram
# 17        Nagaland
# 18          Odisha
# 19          Punjab
# 20       Rajasthan
# 21          Sikkim
# 22           Tamil
# 23       Telangana
# 24         Tripura
# 25           Uttar
# 26     Uttarakhand
# 27            West
# 28           Total
# 29         Andaman
# 30      Chandigarh
# 31           Dadra
# 32           Delhi
# 33           Jammu
# 34          Ladakh
# 35     Lakshadweep
# 36      Puducherry
# 37           Total
# 38           Total
# Name: State/UT, dtype: object

# %%
df1 = pd.DataFrame({'name':['John','Victor','Michael','Virginia','Mike'], 'Id':[3,4]})

# %%
df2 = pd.DataFrame({'domain':['IT',]})
