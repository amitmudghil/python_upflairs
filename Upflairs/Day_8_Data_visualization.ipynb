# %%
# Data Visualization
####################
# Line plot/graph                 ->  Continuous Numerical data
# Histogram                       ->  Frequency of data  ->  continuopus numerical data
# box plot                        
# Bar Graph                       ->  Categorical data + Continuous numerical data
# Hexbin plot
# KDE plot
# Scatter plot
# violin plot
# Swarm plot

# %%
from IPython.display import display, Image

# %%
#Bar graph
display(Image(url='https://chartio.com/images/tutorials/charts/grouped-bar-charts/grouped-bar-example-1.png'))
# Out:
# <img src="https://chartio.com/images/tutorials/charts/grouped-bar-charts/grouped-bar-example-1.png"/>

# %%
# Line plot
display(Image(url='https://th.bing.com/th/id/OIP.o3nuGQDkpvamh5X5d2_hWQHaFj?w=243&h=182&c=7&r=0&o=5&dpr=1.3&pid=1.7'))
# Out:
# <img src="https://th.bing.com/th/id/OIP.o3nuGQDkpvamh5X5d2_hWQHaFj?w=243&h=182&c=7&r=0&o=5&dpr=1.3&pid=1.7"/>

# %%
# Histogram
display(Image(url='https://th.bing.com/th/id/OIP.lhVj7JglotIL-uMWXoUfkgHaFj?w=233&h=180&c=7&r=0&o=5&dpr=1.3&pid=1.7'))
# Out:
# <img src="https://th.bing.com/th/id/OIP.lhVj7JglotIL-uMWXoUfkgHaFj?w=233&h=180&c=7&r=0&o=5&dpr=1.3&pid=1.7"/>

# %%
# Box plot
display(Image(url='https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTF0l3oKAX4U6s-mwuH9oVvHYdsRAeKzxLz3Q&usqp=CAU'))
# Out:
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTF0l3oKAX4U6s-mwuH9oVvHYdsRAeKzxLz3Q&usqp=CAU"/>

# %%
# Hex bin plot
display(Image(url='data:image/jpeg;base64,...'))
# Out:
# <img src="data:image/jpeg;base64,..."/>

# %%
# KDE plot
display(Image(url='data:image/png;base64,...'))
# Out:
# <img src="data:image/png;base64,..."/>

# %%
# Violin plot
display(Image(url='data:image/png;base64,...'))
# Out:
# <img src="data:image/png;base64,..."/>

# %%
# Swarm plot
display(Image(url='data:image/png;base64,...'))
# Out:
# <img src="data:image/png;base64,..."/>
